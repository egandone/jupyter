# %%
# %load_ext watermark
# %watermark
# Out:
# 2020-02-25T20:28:53-05:00
#
# CPython 3.8.1
# IPython 7.12.0
#
# compiler   : GCC 5.4.0 20160609
# system     : Linux
# release    : 4.9.54-ti-r68
# machine    : armv7l
# processor  : armv7l
# CPU cores  : 1
# interpreter: 32bit

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='randome diagonal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.7666666666667">

# %%
import numpy as np
