# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import imutils

# %load_ext watermark
# %watermark

print(f'OpenCV: {cv2.__version__}')
# Out:
# 2020-10-03T09:34:24-04:00
#
# CPython 3.8.3rc1
# IPython 7.14.0
#
# compiler   : GCC 8.3.0
# system     : Linux
# release    : 4.19.88-v8+
# machine    : aarch64
# processor  :
# CPU cores  : 4
# interpreter: 32bit
# OpenCV: 4.1.1

# %%
img = cv2.imread('messi5.jpg', 0)

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
pi04_current = imutils.url_to_image("http://192.168.1.176:8081/0/current")
plt.figure('pi04')
plt.imshow(imutils.opencv2matplotlib(pi04_current))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
pi05_current = imutils.url_to_image("http://192.168.2.167:8081/0/current")
plt.figure('pi05')
plt.imshow(imutils.opencv2matplotlib(pi05_current))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
pi07_current = imutils.url_to_image("http://192.168.1.109:8081/0/current")
plt.figure('pi07')
plt.imshow(imutils.opencv2matplotlib(pi07_current))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
pi09_current = imutils.url_to_image("http://192.168.2.45:8081/0/current")
plt.figure('pi09')
plt.imshow(imutils.opencv2matplotlib(pi09_current))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
debian10b_current = imutils.url_to_image("http://192.168.1.106:8081/0/current")
plt.figure('debian10b')
plt.imshow(imutils.opencv2matplotlib(debian10b_current))
plt.xticks([]), plt.yticks([])
plt.show()
