# %%
# %matplotlib notebook
# Use %matplotlib inline to get simple, non-interactive graphs
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='randome diagonal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="952.6666666666666">

# %%
class Class:
    def __init__(self):
        print('init')
        
    def doit(self):
        print('doit')

# %%
c = Class()
# Out:
# init

# %%
c.doit()
# Out:
# doit

# %%
from queue import Queue
q1 = Queue()
dir(q1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get',
#  '_init',
#  '_put',
#  '_qsize',
#  'all_tasks_done',
#  'empty',
#  'full',
#  'get',
#  'get_nowait',
#  'join',
#  'maxsize',
#  'mutex',
#  'not_empty',
#  'not_full',
#  'put',
#  'put_nowait',
#  'qsize',
#  'queue',
#  'task_done',
#  'unfinished_tasks']

# %%
q.put(1)
q.qsize()
# Out:
# 2

# %%
type(q)
# Out:
# queue.Queue

# %%
q.maxsize
# Out:
# 0
