# %%
# %load_ext watermark
# %watermark
# Out:
# 2020-05-18T09:19:10-04:00
#
# CPython 3.7.3
# IPython 7.14.0
#
# compiler   : GCC 8.3.0
# system     : Linux
# release    : 4.19.97-v7+
# machine    : armv7l
# processor  :
# CPU cores  : 4
# interpreter: 32bit

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='randome diagonal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import math
import numpy as np
x = np.arange(-math.pi, math.pi, math.pi/10)
y = np.sin(x)
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
