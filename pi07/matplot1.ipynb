# %%
# %load_ext watermark
# %watermark
# Out:
# 2020-02-25T20:59:07-05:00
#
# CPython 3.8.1
# IPython 7.12.0
#
# compiler   : GCC 6.3.0 20170516
# system     : Linux
# release    : 4.9.35-v7+
# machine    : armv7l
# processor  :
# CPU cores  : 4
# interpreter: 32bit

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='randome diagonal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4762199111423">

# %%
import math
import numpy as np
x = np.arange(-math.pi, math.pi, math.pi/10)
y = np.sin(x)
plt.plot(x, y)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.4762199111423">
