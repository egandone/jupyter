# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import imutils

# %load_ext watermark
# %watermark

print(f'OpenCV: {cv2.__version__}')
# Out:
# Last updated: 2022-10-07T01:57:33.115446+00:00
#
# Python implementation: CPython
# Python version       : 3.10.7
# IPython version      : 8.5.0
#
# Compiler    : GCC 10.2.1 20210110
# OS          : Linux
# Release     : 5.10.120-ti-arm64-r64
# Machine     : aarch64
# Processor   :
# CPU cores   : 2
# Architecture: 64bit
#
# OpenCV: 4.6.0

# %%
img = cv2.imread('messi5.jpg', 0)

plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
pi04_current = imutils.url_to_image("http://pi04:8081/0/current")
plt.figure('pi04')
plt.imshow(imutils.opencv2matplotlib(pi04_current))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
pi07_current = imutils.url_to_image("http://pi07:8081/0/current")
plt.figure('pi07')
plt.imshow(imutils.opencv2matplotlib(pi07_current))
plt.xticks([]), plt.yticks([])
plt.show()

# %%
pi09_current = imutils.url_to_image("http://pi09:8081/0/current")
plt.figure('pi09')
plt.imshow(imutils.opencv2matplotlib(pi09_current))
plt.xticks([]), plt.yticks([])
plt.show()
