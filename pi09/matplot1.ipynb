# %%
# %load_ext watermark
# %watermark
# Out:
# 2020-02-23T19:52:12-05:00
#
# CPython 3.8.1
# IPython 7.12.0
#
# compiler   : GCC 6.3.0 20170516
# system     : Linux
# release    : 4.19.66-v7+
# machine    : armv7l
# processor  :
# CPU cores  : 4
# interpreter: 32bit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='random diagonal')
plt.show()
