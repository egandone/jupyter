# %%
# %load_ext watermark
# %watermark
# Out:
# 2020-05-18T10:36:48-04:00
#
# CPython 3.7.3
# IPython 7.14.0
#
# compiler   : GCC 8.3.0
# system     : Linux
# release    : 4.19.97-v7+
# machine    : armv7l
# processor  :
# CPU cores  : 4
# interpreter: 32bit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([[0,0],[1,1]], linewidth=4, label='random diagonal')
plt.show()
